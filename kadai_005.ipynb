# %%
print("こんにちは")
print("今日はいい天気ですね")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5417/1038694521.py in <cell line: 0>()
# ----> 1 print(こんにちは)
#       2 print(今日はいい天気ですね)
#
# NameError: name 'こんにちは' is not defined
